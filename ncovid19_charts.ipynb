# %% [markdown]
# <a href="https://colab.research.google.com/github/irkcow/ncovid19/blob/master/ncovid19_charts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import itertools
#!pip install -q xlrd
#print ('fddd')

import pandas as pd
#!pip install  cufflinks
#import cufflinks as cf
#!ls 8../ -ll
#df = pd.read_excel('exported.xlsx')
from google.colab import drive
#drive.mount('/content/drive')
#!ls -ll '/content/drive/My Drive/'
#df= pd.read_excel('/content/drive/My Drive/2020.02.07_data_charts.xlsx')
#df= pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vTahn8ssNCLX5OU159VNrjg8jQSD3U7lhQ-hq2LAvc_cU8Ot0aH-Eda8T9c-lSwwg/pub?gid=514500894&single=true&output=csv',thousands='B')
df= pd.read_excel('https://docs.google.com/spreadsheets/d/e/2PACX-1vTahn8ssNCLX5OU159VNrjg8jQSD3U7lhQ-hq2LAvc_cU8Ot0aH-Eda8T9c-lSwwg/pub?output=xlsx')
#df['infected'].astype('float')
df.set_index('data', inplace=True)
#df['infected']=df['infected'].str.replace('[^\d.,e+-]', '').astype('float')
#df=df.applymap(lambda x: str(x).replace('[\sB]','')).astype('float')
#df.info()
df
# Out:
#             month  day  infected  ...  death_pl  cured  cured_pl
# data                              ...
# 2020-01-11      1   11        41  ...         0      0         0
# 2020-01-12      1   12        41  ...         0      0         0
# 2020-01-13      1   13        41  ...         0      0         0
# 2020-01-14      1   14        41  ...         0      0         0
# 2020-01-15      1   15        41  ...         0      0         0
# 2020-01-16      1   16        41  ...         0      0         0
# 2020-01-17      1   17        45  ...         0      0         0
# 2020-01-18      1   18        62  ...         0      0         0
# 2020-01-19      1   19       198  ...         0      0         0
# 2020-01-20      1   20       218  ...         0      0         0
# 2020-01-21      1   21       320  ...         0      0         0
# 2020-01-22      1   22       478  ...         0      0         0
# 2020-01-23      1   23       639  ...        26      0         0
# ...

# %%
#import cufflinks as cf
#cf.go_offline()

#from plotly.offline import init_notebook_mode
#init_notebook_mode(connected=False)
#configure_plotly_browser_state()

#cf.datagen.lines().iplot(kind='scatter',xTitle='Dates',yTitle='Returns',title='Cufflinks - Line Chart')

# %%
#! pip -q install plotly
import plotly.graph_objects as go
#%matplotlib inline
fig = go.Figure( go.Scatter(y=df['infected'], x=df.index, mode='lines+markers' ) )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="947a1108-f5c7-4450-a207-804153c5ffe4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("947a1108-f5c7-4450-a207-804153c5ffe4")) {
#                     Plotly.newPlot(
#                         '947a1108-f5c7-4450-a207-804153c5ffe4',
# ...

# %%
fig = go.Figure( go.Scatter(y=df.query('infected>0')['inf_pl'], x=df.index, mode='lines+markers' ) )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="4387eee1-1480-49af-b0f5-802bba717f50" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4387eee1-1480-49af-b0f5-802bba717f50")) {
#                     Plotly.newPlot(
#                         '4387eee1-1480-49af-b0f5-802bba717f50',
# ...

# %%
fig = go.Figure( go.Scatter(y=df.query('infected>0')['infected'].pct_change()*100, x=df.index, text=df['infected'], mode='lines+markers'))
fig.update_layout(title='Прирост заболеваемости в процентах', xaxis_title="Дата", yaxis_title="Проценты")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="2fc8e9fa-5bc4-4610-b1da-e7fd2e91f765" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2fc8e9fa-5bc4-4610-b1da-e7fd2e91f765")) {
#                     Plotly.newPlot(
#                         '2fc8e9fa-5bc4-4610-b1da-e7fd2e91f765',
# ...

# %%
fig = go.Figure( go.Scatter(y=df.query('infected>0')['infected'].diff(),x=df.index,text=df['infected'] ) )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="60b29c52-ce51-4eb7-b591-511124bd135e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("60b29c52-ce51-4eb7-b591-511124bd135e")) {
#                     Plotly.newPlot(
#                         '60b29c52-ce51-4eb7-b591-511124bd135e',
# ...

# %%
#import plotly
#from plotly.graph_objs import Scatter, Layout
import plotly.express as px

#plotly.offline.init_notebook_mode(connected=True)

fig=px.scatter(x=[1, 2, 3, 4], y=[4, 3, 2, 1])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="16956443-0100-49cf-a300-2bbf2c17f680" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("16956443-0100-49cf-a300-2bbf2c17f680")) {
#                     Plotly.newPlot(
#                         '16956443-0100-49cf-a300-2bbf2c17f680',
# ...

# %%
from plotly.subplots import make_subplots

fig_sub=make_subplots(rows=4,cols=1, shared_xaxes=True,vertical_spacing=0.01)
fig_sub.add_trace(go.Scatter(y=df.query('infected>0')['infected'], x=df.index, text=df['infected'], mode='lines+markers'),row=1,col=1)
fig_sub.add_trace(go.Scatter(y=df.query('infected>0')['new_infected'], x=df.index, text=df['infected'], mode='lines+markers'),row=1,col=1)

fig_sub.add_trace(go.Scatter(y=df.query('infected>0')['infected'], x=df.index, text=df['infected'], mode='lines+markers'),row=2,col=1)
fig_sub.add_trace(go.Scatter(y=df.query('infected>0')['new_infected'], x=df.index, text=df['infected'], mode='lines+markers'),row=2,col=1)

fig_sub.add_trace(go.Scatter(y=df.query('infected>0')['infected'].diff(), x=df.index, text=df['infected'], mode='lines+markers'),row=3,col=1)
fig_sub.add_trace(go.Scatter(y=df.query('infected>0')['new_infected'].diff(), x=df.index, text=df['infected'], mode='lines+markers'),row=3,col=1)

fig_sub.add_trace(go.Scatter(y=df.query('infected>0')['infected'].pct_change()*100, x=df.index, text=df['infected'], mode='lines+markers'),row=4,col=1)
fig_sub.add_trace(go.Scatter(y=df.query('infected>0')['new_infected'].pct_change()*100, x=df.index, text=df['infected'], mode='lines+markers'),row=4,col=1)

#fig = go.Figure( go.Scatter(y=df.query('infected>0')['infected'].pct_change()*100, x=df.index, text=df['infected'], mode='lines+markers'))

#fig.show()
fig_sub['layout']['yaxis1'].update(title='Absolute')
fig_sub['layout']['yaxis2'].update(title='Logarithmic', type='log')
fig_sub['layout']['yaxis3'].update(title='Diff')
fig_sub['layout']['yaxis4'].update(title='Percent')
#fig_sub.update_layout(height=1000,title='Прирост заболеваемости в процентах', xaxis_title="Дата", yaxis_title="Проценты")
fig_sub.update_layout(height=1000,title='Incindence covid-19', xaxis_title="Дата")
fig_sub.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="2e56bd55-31cd-45d8-b035-b2fdd958c0eb" class="plotly-graph-div" style="height:1000px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2e56bd55-31cd-45d8-b035-b2fdd958c0eb")) {
#                     Plotly.newPlot(
#                         '2e56bd55-31cd-45d8-b035-b2fdd958c0eb',
# ...
